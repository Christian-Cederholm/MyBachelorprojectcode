# %%
import requests
import json

# %%
r=requests.get('https://sandbox.zenodo.org/api/deposit/depositions')
r.status_code
r.json()
# Out:
# {'message': "The server could not verify that you are authorized to access the URL requested.  You either supplied the wrong credentials (e.g. a bad password), or your browser doesn't understand how to supply the credentials required.",
#  'status': 401}

# %%
import requests
import json

#Json part

'''Get the url'''
params = (
    ('detail', 'contributions'),
)

response = requests.get('https://indico.cern.ch/export/event/867789.json', params=params)


'''Change to JSON'''
Jsonresponse = response.json()

'''Get into folder'''
Jsonresponse=Jsonresponse["results"][0]["contributions"]

'''To save the correct folder when it is found'''
result=None


'''Find the folder with the right id'''
for item in Jsonresponse:
    result=item
    if result["id"]=="409":
        break;

#Fix for multiple files?
# Find the file and the path to download the file
data_file_names=result["folders"][0]["attachments"][0]["filename"]
file_download_path=result["folders"][0]["attachments"][0]["download_url"]

description=result["description"]
Title=result["title"]
Upload_type=None

#Fix for multiple authors
Author_Names=result["primaryauthors"][0]["fullName"]
Author_Affiliation=result["primaryauthors"][0]["affiliation"]


#data_file_names=result["folders"]["attachments"]["filename"]


if type(data_file_names)!=str:
    print("file name must be string")
if type(file_download_path)!=str:
    print("file download path must be string")
if type(description)!=str:
    print("description must be string")

print(data_file_names)
print(file_download_path)
print(description)
print(Title)
print(Author_Names)
print(Author_Affiliation)
# Out:
# Poster_HSFWLCG.pdf
# <class 'str'>
# https://indico.cern.ch/event/867789/contributions/3754987/attachments/1989047/3315426/Poster_HSFWLCG.pdf
# Together with a Lund University Bachelor's student, we are testing scripts that will publish the slides of this workshop to Zenodo (https://zenodo.org), similarly to what was done for the CHEP conference (https://zenodo.org/communities/chep-2019?page=1&size=20). This entry is used for testing the Indico and Zenodo APIs until we have actual contributions.
# Test entry
# Doglioni, Caterina
# Lund University (SE)

# %%
import requests
import json

#Json part

'''Get the url'''
params = (
    ('detail', 'contributions'),
)

response = requests.get('https://indico.cern.ch/export/event/867789.json', params=params)


'''Change to JSON'''
Jsonresponse = response.json()

'''Get into folder'''
Jsonresponse=Jsonresponse["results"][0]["contributions"]

'''To save the correct folder when it is found'''
result=None


'''Find the folder with the right id'''
for item in Jsonresponse:
    result=item
    if result["id"]=="409":
        break;

#Fix for multiple files?
# Find the file and the path to download the file
data_file_names=result["folders"][0]["attachments"][0]["filename"]
file_download_path=result["folders"][0]["attachments"][0]["download_url"]

description=result["description"]
Title=result["title"]
Upload_type=None

#Fix for multiple authors
Author_Names=result["primaryauthors"][0]["fullName"]
Author_Affiliation=result["primaryauthors"][0]["affiliation"]


#data_file_names=result["folders"]["attachments"]["filename"]


if type(data_file_names)!=str:
    print("file name must be string")
if type(file_download_path)!=str:
    print("file download path must be string")
if type(description)!=str:
    print("description must be string")

print(data_file_names)
print(file_download_path)
print(description)
print(Title)
print(Author_Names)
print(Author_Affiliation)


#Zenodo part
# Access token is like a password 
Access_Token="Something"


headers = {"Content-Type": "application/json"}


#create preliminary zenodo entry
r=requests.post('https://sandbox.zenodo.org/api/deposit/depositions', 
                params={'access_token': "q1UUjEZ4RGi2lhiPzZQmRcltmTdZqunk6gWRLyyWmozTBRHZyG69yBUQNOKQ"}, json={},headers=headers)

deposition_id= r.json()['id']

data={'name':'Poster_HSFWLCG.pdf'}

#Files to upload
files={'file': open('/home/komtaq/Downloads/Poster_HSFWLCG.pdf', 'rb')}

#Put in files
r=requests.post('https://sandbox.zenodo.org/api/deposit/depositions/%s/files' % deposition_id, 
                params={'access_token': "q1UUjEZ4RGi2lhiPzZQmRcltmTdZqunk6gWRLyyWmozTBRHZyG69yBUQNOKQ"}, data=data, files=files)

test_entry_description="Together with a Lund University Bachelor's student, we are testing scripts that will publish the slides of this workshop to Zenodo (https://zenodo.org), similarly to what was done for the CHEP conference (https://zenodo.org/communities/chep-2019?page=1&size=20). This entry is used for testing the Indico and Zenodo APIs until we have actual contributions."

data={ 'metadata': {'title': 'Test entry', 'upload_type': 'poster', 'description': test_entry_description,
                    'creators': [{'name': 'Doglioni, Caterina', 'affiliation': 'Lund University (SE)'}]}}

#In
r=requests.put('https://sandbox.zenodo.org/api/deposit/depositions/%s' % deposition_id, 
               params={'access_token': "q1UUjEZ4RGi2lhiPzZQmRcltmTdZqunk6gWRLyyWmozTBRHZyG69yBUQNOKQ"}, data=json.dumps(data), headers=headers)

# %%
import requests
import json

#Json part

'''Get the url'''
params = (
    ('detail', 'contributions'),
)

response = requests.get('https://indico.cern.ch/export/event/867789.json', params=params)


'''Change to JSON'''
Jsonresponse = response.json()

'''Get into folder'''
Jsonresponse=Jsonresponse["results"][0]["contributions"]

'''To save the correct folder when it is found'''
result=None


'''Find the folder with the right id'''
for item in Jsonresponse:
    result=item
    if result["id"]=="409":
        break;

#Fix for multiple files?
# Find the file and the path to download the file
data_file_names=result["folders"][0]["attachments"][0]["filename"]
file_download_path=result["folders"][0]["attachments"][0]["download_url"]

description=result["description"]
Title=result["title"]
Upload_type=None

#Fix for multiple authors
Author_Names=result["primaryauthors"][0]["fullName"]
Author_Affiliation=result["primaryauthors"][0]["affiliation"]


if type(data_file_names)!=str:
    print("file name must be string")
if type(file_download_path)!=str:
    print("file download path must be string")
if type(description)!=str:
    print("description must be string")

'''
print(data_file_names)
print(file_download_path)
print(description)
print(Title)
print(Author_Names)
print(Author_Affiliation)
'''

#Zenodo part
#Fix so user can choose upload type
Uploadtype="nan"

# Access token to Zenodo
Access_Token="Something"
if type(Access_Token)!=str:
    print("file name must be string")


headers = {"Content-Type": "application/json"}


#create preliminary zenodo entry
r=requests.post('https://sandbox.zenodo.org/api/deposit/depositions', 
                params={'access_token': Access_Token}, json={},headers=headers)

deposition_id= r.json()['id']

# Gives your uploaded file the correct name
data={'name': data_file_name}

#File to upload
files={'file': open(file_download_path, 'rb')}

#Put in file
r=requests.post('https://sandbox.zenodo.org/api/deposit/depositions/%s/files' % deposition_id, 
                params={'access_token': Access_Token}, data=data, files=files)

#All data about the entry
data={ 'metadata': {'title': Title, 'upload_type': 'poster', 'description': description,
                    'creators': [{'name': Author_Names, 'affiliation': Author_Affiliation}]}}

#Insert data into entry
r=requests.put('https://sandbox.zenodo.org/api/deposit/depositions/%s' % deposition_id, 
               params={'access_token': Access_Token}, data=json.dumps(data), headers=headers)
# Out:
# Poster_HSFWLCG.pdf
# https://indico.cern.ch/event/867789/contributions/3754987/attachments/1989047/3315426/Poster_HSFWLCG.pdf
# Together with a Lund University Bachelor's student, we are testing scripts that will publish the slides of this workshop to Zenodo (https://zenodo.org), similarly to what was done for the CHEP conference (https://zenodo.org/communities/chep-2019?page=1&size=20). This entry is used for testing the Indico and Zenodo APIs until we have actual contributions.
# Test entry
# Doglioni, Caterina
# Lund University (SE)

# %%
import requests
import json

#Json part

'''Get the url'''
params = (
    ('detail', 'contributions'),
)

response = requests.get('https://indico.cern.ch/export/event/773049.json', params=params)


'''Change to JSON'''
Jsonresponse = response.json()

'''Get into folder'''
Jsonresponse=Jsonresponse["results"][0]["contributions"]

'''To save the correct folder when it is found'''
result=None


'''Find the folder with the right id'''
for item in Jsonresponse:
    result=item
    if result["id"]=="409":
        break;

#print(json.dumps(result, indent=4, separators=(',', ': ')))

#Zenodo part

Access_Token="q1UUjEZ4RGi2lhiPzZQmRcltmTdZqunk6gWRLyyWmozTBRHZyG69yBUQNOKQ"


headers = {"Content-Type": "application/json"}


#create preliminary zenodo entry
r=requests.post('https://sandbox.zenodo.org/api/deposit/depositions', 
                params={'access_token': "q1UUjEZ4RGi2lhiPzZQmRcltmTdZqunk6gWRLyyWmozTBRHZyG69yBUQNOKQ"}, json={},headers=headers)

deposition_id= r.json()['id']

data={'name':'Poster_HSFWLCG.pdf'}

#Files to upload
files={'file': open('/home/komtaq/Downloads/Poster_HSFWLCG.pdf', 'rb')}

#Put in files
r=requests.post('https://sandbox.zenodo.org/api/deposit/depositions/%s/files' % deposition_id, 
                params={'access_token': "q1UUjEZ4RGi2lhiPzZQmRcltmTdZqunk6gWRLyyWmozTBRHZyG69yBUQNOKQ"}, data=data, files=files)

test_entry_description="Together with a Lund University Bachelor's student, we are testing scripts that will publish the slides of this workshop to Zenodo (https://zenodo.org), similarly to what was done for the CHEP conference (https://zenodo.org/communities/chep-2019?page=1&size=20). This entry is used for testing the Indico and Zenodo APIs until we have actual contributions."

data={ 'metadata': {'title': 'Test entry', 'upload_type': 'poster', 'description': test_entry_description,
                    'creators': [{'name': 'Doglioni, Caterina', 'affiliation': 'Lund University (SE)'}]}}

#In
r=requests.put('https://sandbox.zenodo.org/api/deposit/depositions/%s' % deposition_id, 
               params={'access_token': "q1UUjEZ4RGi2lhiPzZQmRcltmTdZqunk6gWRLyyWmozTBRHZyG69yBUQNOKQ"}, data=json.dumps(data), headers=headers)
# Out:
# {
#     "startDate": {
#         "date": "2019-11-07",
#         "tz": "Europe/Zurich",
#         "time": "06:45:00"
#     },
#     "endDate": {
#         "date": "2019-11-07",
#         "tz": "Europe/Zurich",
#         "time": "07:00:00"
#     },
#     "keywords": [],
#     "roomFullname": "Hall F",
#     "friendly_id": 409,
#     "duration": 15,
#     "id": "409",
#     "speakers": [
#         {
#             "_type": "ContributionParticipation",
#             "last_name": "Rodriguez Rodriguez",
#             "emailHash": "e210cf68c3d4de1189d2abb66291965e",
#             "first_name": "Diego",
#             "affiliation": "CERN",
#             "db_id": 4461289,
#             "_fossil": "contributionParticipationMetadata",
#             "person_id": 4520506,
#             "fullName": "Rodriguez Rodriguez, Diego",
#             "id": "4461289"
#         }
#     ],
#     "board_number": "",
#     "title": "Hybrid analysis pipelines in the REANA reproducible analysis platform",
# ...

# %%
import requests
import json

Access_Token="q1UUjEZ4RGi2lhiPzZQmRcltmTdZqunk6gWRLyyWmozTBRHZyG69yBUQNOKQ"


headers = {"Content-Type": "application/json"}


#create preliminary zenodo entry
r=requests.post('https://sandbox.zenodo.org/api/deposit/depositions', 
                params={'access_token': "q1UUjEZ4RGi2lhiPzZQmRcltmTdZqunk6gWRLyyWmozTBRHZyG69yBUQNOKQ"}, json={},headers=headers)

deposition_id= r.json()['id']

data={'name':'Poster_HSFWLCG.pdf'}

#Files to upload
files={'file': open('/home/komtaq/Downloads/Poster_HSFWLCG.pdf', 'rb')}

#Put in files
r=requests.post('https://sandbox.zenodo.org/api/deposit/depositions/%s/files' % deposition_id, 
                params={'access_token': "q1UUjEZ4RGi2lhiPzZQmRcltmTdZqunk6gWRLyyWmozTBRHZyG69yBUQNOKQ"}, data=data, files=files)

test_entry_description="Together with a Lund University Bachelor's student, we are testing scripts that will publish the slides of this workshop to Zenodo (https://zenodo.org), similarly to what was done for the CHEP conference (https://zenodo.org/communities/chep-2019?page=1&size=20). This entry is used for testing the Indico and Zenodo APIs until we have actual contributions."

data={ 'metadata': {'title': 'Test entry', 'upload_type': 'poster', 'description': test_entry_description,
                    'creators': [{'name': 'Doglioni, Caterina', 'affiliation': 'Lund University (SE)'}]}}

#In
r=requests.put('https://sandbox.zenodo.org/api/deposit/depositions/%s' % deposition_id, 
               params={'access_token': "q1UUjEZ4RGi2lhiPzZQmRcltmTdZqunk6gWRLyyWmozTBRHZyG69yBUQNOKQ"}, data=json.dumps(data), headers=headers)
